# %% [markdown]
# ### Loops
# 1. While
# 2. For
# 3. Do-while
#
# #### Successful Programs
# 1. The program must end
# 2. The program must produce correct answers
#
# ### Important Ideas
# 1. break
# 2. continue

# %%
while(CONDITION){
    # Operation
    # chainge the loop variable(i,j,k)
}

# %%
# Calculator
while(True):
    print("Choose your option :")

    print("1.Addition")
    print("2.Subtraction")
    print("3.Multiplication")
    print("4.Power")
    print("5.Division")
    print("6.Mod")
    print("7.OFF")
    print("______________________")

    option =input(":")

    match option:
        case"1":
            num1=int(input("enter your 1st number: "))
            num2=int(input("enter your 2nd number: "))
            sum=(num1+num2)
            print(sum)
        case"2":
            num1=int(input("enter your 1st number: "))
            num2=int(input("enter your 2nd number: "))
            subtraction=(num1-num2)
            print(subtraction)
        case"3":
            num1=int(input("enter your 1st number: "))
            num2=int(input("enter your 2nd number: "))
            multiplication=(num1*num2)
            print(multiplication)
        case"4":
            num1=int(input("enter your 1st number: "))
            num2=int(input("enter your 2nd number: "))
            power=(num1**num2)
            print(power)
        case"5":
            num1=int(input("enter your 1st number: "))
            num2=int(input("enter your 2nd number: "))
            division=(num1/num2)
            print(division)
        case"6":
            num1=int(input("enter your 1st number: "))
            num2=int(input("enter your 2nd number: "))
            mod=(num1%num2)
            print(mod)
        case"7":
            break
        case _:
            print("Invalid option")
            
print("The calculator has been turned off!")

# %%
# We want to print lines except for when we find numbers divisible by 3
loopingCount=10
i=1
while(i<=loopingCount):
    if(i%3==0):
        i=i+1
        continue
    print(i,". Hello world")
    i=i+1

# %%
# *
# **
# ***
# ****
# *****
n=5
i=0
while(i<n):
    j=0
    while(j<=i):
        print("*",end="")
        j=j+1
    print("")
    i=i+1

# %%
# 0    * 
# 1   * * 
# 2  * * * 
# 3 * * * * 
# 4* * * * * 
n=100
i=0
while(i<n):
    j=0
    while(j<=n-1-i):
        print(" ",end="")
        j=j+1
    k=0
    while(k<=i):
        print("* ",end="")
        k=k+1
    print("")
    i=i+1

# %%
# Homework
#* * * * * 
# * * * * 
#  * * * 
#   * * 
#    * 

#    * 
#   * * 
#  * * * 
# * * * * 
#* * * * * 
# * * * * 
#  * * * 
#   * * 
#    *
